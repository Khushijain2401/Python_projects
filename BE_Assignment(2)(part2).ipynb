# %%
import pandas as pd

# %%
data=pd.read_csv("/content/disney_princess_popularity_dataset_300_rows (1).csv")

# %%
data
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0     Pocahontas  Pocahontas's Adventure            1977                   85
# 1          Mulan       Mulan's Adventure            1995                   85
# 2           Raya        Raya's Adventure            1989                  110
# 3           Anna        Anna's Adventure            1940                   78
# 4          Mulan       Mulan's Adventure            1943                  103
# ..           ...                     ...             ...                  ...
# 295       Merida      Merida's Adventure            2001                   95
# 296        Belle       Belle's Adventure            2006                   76
# 297         Anna        Anna's Adventure            2020                   70
# 298        Tiana       Tiana's Adventure            1937                   71
# 299        Mulan       Mulan's Adventure            1938                  105
#
# ...

# %%
data["HairColor"].unique()
# Out:
# array(['Brown', 'Blonde', 'White', 'Black', 'Red'], dtype=object)

# %%
data[data["HairColor"]=="Black"]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 7       Rapunzel    Rapunzel's Adventure            1987                   79
# 9           Anna        Anna's Adventure            2010                  108
# 24         Tiana       Tiana's Adventure            2019                  108
# 29         Mulan       Mulan's Adventure            1983                   70
# 35          Raya        Raya's Adventure            2007                   87
# 40        Merida      Merida's Adventure            1993                   74
# 41      Rapunzel    Rapunzel's Adventure            1977                   70
# 53         Tiana       Tiana's Adventure            1991                   71
# 58         Belle       Belle's Adventure            1937                  105
# 59          Anna        Anna's Adventure            1991                  105
# 85        Aurora      Aurora's Adventure            1952                   75
# ...

# %%
data["EyeColor"].unique()
# Out:
# array(['Green', 'Brown', 'Hazel', 'Grey', 'Blue'], dtype=object)

# %%
data[data["EyeColor"]=="Blue"]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 5        Jasmine     Jasmine's Adventure            2010                   78
# 6     Snow White  Snow White's Adventure            1986                   97
# 20        Aurora      Aurora's Adventure            1977                   72
# 30       Jasmine     Jasmine's Adventure            1996                   82
# 33          Raya        Raya's Adventure            1997                  104
# ..           ...                     ...             ...                  ...
# 280       Aurora      Aurora's Adventure            1972                   95
# 286   Snow White  Snow White's Adventure            2005                   96
# 292         Anna        Anna's Adventure            1956                   95
# 297         Anna        Anna's Adventure            2020                   70
# 298        Tiana       Tiana's Adventure            1937                   71
#
# ...

# %%
data[data["FirstMovieYear"]<1990]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0     Pocahontas  Pocahontas's Adventure            1977                   85
# 2           Raya        Raya's Adventure            1989                  110
# 3           Anna        Anna's Adventure            1940                   78
# 4          Mulan       Mulan's Adventure            1943                  103
# 6     Snow White  Snow White's Adventure            1986                   97
# ..           ...                     ...             ...                  ...
# 291   Cinderella  Cinderella's Adventure            1964                   82
# 292         Anna        Anna's Adventure            1956                   95
# 293        Moana       Moana's Adventure            1961                   96
# 298        Tiana       Tiana's Adventure            1937                   71
# 299        Mulan       Mulan's Adventure            1938                  105
#
# ...

# %%
data[data["SidekickType"]!="None"]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0     Pocahontas  Pocahontas's Adventure            1977                   85
# 1          Mulan       Mulan's Adventure            1995                   85
# 2           Raya        Raya's Adventure            1989                  110
# 3           Anna        Anna's Adventure            1940                   78
# 4          Mulan       Mulan's Adventure            1943                  103
# ..           ...                     ...             ...                  ...
# 295       Merida      Merida's Adventure            2001                   95
# 296        Belle       Belle's Adventure            2006                   76
# 297         Anna        Anna's Adventure            2020                   70
# 298        Tiana       Tiana's Adventure            1937                   71
# 299        Mulan       Mulan's Adventure            1938                  105
#
# ...

# %%
data["FirstMovieTitle"].unique()
# Out:
# array(["Pocahontas's Adventure", "Mulan's Adventure", "Raya's Adventure",
#        "Anna's Adventure", "Jasmine's Adventure",
#        "Snow White's Adventure", "Rapunzel's Adventure",
#        "Belle's Adventure", "Cinderella's Adventure", "Ariel's Adventure",
#        "Elsa's Adventure", "Aurora's Adventure", "Moana's Adventure",
#        "Tiana's Adventure", "Merida's Adventure"], dtype=object)

# %%
data[data["FirstMovieYear"]>2010]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 19          Raya        Raya's Adventure            2011                   78
# 21         Moana       Moana's Adventure            2021                  101
# 23    Cinderella  Cinderella's Adventure            2011                   99
# 24         Tiana       Tiana's Adventure            2019                  108
# 47        Merida      Merida's Adventure            2012                   89
# 50         Tiana       Tiana's Adventure            2015                  100
# 52         Mulan       Mulan's Adventure            2014                   77
# 78      Rapunzel    Rapunzel's Adventure            2019                  106
# 89    Pocahontas  Pocahontas's Adventure            2013                   70
# 103        Mulan       Mulan's Adventure            2019                   85
# 107        Tiana       Tiana's Adventure            2018                   80
# ...

# %%
data[data["NumberOfSongs"]>3]
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0     Pocahontas  Pocahontas's Adventure            1977                   85
# 2           Raya        Raya's Adventure            1989                  110
# 4          Mulan       Mulan's Adventure            1943                  103
# 5        Jasmine     Jasmine's Adventure            2010                   78
# 8           Anna        Anna's Adventure            2007                   94
# ..           ...                     ...             ...                  ...
# 289       Merida      Merida's Adventure            1953                   83
# 293        Moana       Moana's Adventure            1961                   96
# 294   Pocahontas  Pocahontas's Adventure            2019                   95
# 295       Merida      Merida's Adventure            2001                   95
# 298        Tiana       Tiana's Adventure            1937                   71
#
# ...
