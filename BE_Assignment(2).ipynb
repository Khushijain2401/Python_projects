# %%
import pandas as pd
data=pd.read_csv("/content/car_price_dataset.csv")
print(data["Brand"].unique())
print(data[data["Brand"]=="Toyota"])
# Out:
# ['Kia' 'Chevrolet' 'Mercedes' 'Audi' 'Volkswagen' 'Toyota' 'Honda' 'BMW'
#  'Hyundai' 'Ford']
#        Brand    Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 5     Toyota    Camry  2007          2.7    Petrol       Automatic   157889
# 9     Toyota     RAV4  2005          3.1    Petrol          Manual   107724
# 21    Toyota     RAV4  2000          4.6    Hybrid  Semi-Automatic    41814
# 22    Toyota     RAV4  2003          2.0  Electric          Manual   136662
# 34    Toyota  Corolla  2010          3.2    Diesel       Automatic   132454
# ...      ...      ...   ...          ...       ...             ...      ...
# 9946  Toyota     RAV4  2000          2.0    Petrol  Semi-Automatic    61667
# 9959  Toyota  Corolla  2006          3.8    Petrol          Manual   138450
# 9965  Toyota    Camry  2017          5.0  Electric          Manual   150119
# 9975  Toyota  Corolla  2015          4.7    Petrol       Automatic   123316
# ...

# %%
data["Fuel_Type"].unique()
# Out:
# array(['Diesel', 'Hybrid', 'Electric', 'Petrol'], dtype=object)

# %%
data[data["Fuel_Type"]=="Diesel"]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 15    Volkswagen      Golf  2007          3.2    Diesel       Automatic
# 18           Kia       Rio  2000          3.4    Diesel  Semi-Automatic
# 25           Kia  Sportage  2011          1.8    Diesel       Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9988         BMW  3 Series  2010          3.0    Diesel          Manual
# 9989      Toyota   Corolla  2003          1.6    Diesel  Semi-Automatic
# 9991    Mercedes   E-Class  2017          1.1    Diesel       Automatic
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
data["Transmission"].unique()
# Out:
# array(['Manual', 'Automatic', 'Semi-Automatic'], dtype=object)

# %%
data["Transmission"]=="Automatic"
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997     True
# 9998     True
# 9999    False
# Name: Transmission, Length: 10000, dtype: bool

# %%
data['Year'] = data['Year'].astype(str)

# %%
data[data["Year"]=="2015"]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 53         Honda     Civic  2015          2.6  Electric  Semi-Automatic
# 62          Ford     Focus  2015          4.8  Electric       Automatic
# 84       Hyundai    Tucson  2015          1.6  Electric          Manual
# 85      Mercedes   C-Class  2015          4.1    Petrol       Automatic
# 130   Volkswagen    Passat  2015          4.7    Diesel          Manual
# ...          ...       ...   ...          ...       ...             ...
# 9881   Chevrolet    Malibu  2015          2.5    Diesel       Automatic
# 9883         BMW  5 Series  2015          4.9    Diesel          Manual
# 9937    Mercedes       GLA  2015          2.6    Diesel       Automatic
# 9952    Mercedes       GLA  2015          4.9  Electric       Automatic
# 9975      Toyota   Corolla  2015          4.7    Petrol       Automatic
#
#       Mileage  Doors  Owner_Count  Price
# 53      66777      5            1  11864
# ...

# %%
data[data["Price"]<10000]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# 5         Toyota     Camry  2007          2.7    Petrol       Automatic
# 7            Kia  Sportage  2001          4.7  Electric  Semi-Automatic
# 8            Kia  Sportage  2014          2.6    Hybrid          Manual
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
data[data['Mileage']<50000]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 11    Volkswagen      Golf  2009          4.5    Hybrid          Manual
# 16       Hyundai   Elantra  2017          2.9  Electric       Automatic
# 17    Volkswagen    Tiguan  2006          4.5  Electric          Manual
# 19      Mercedes       GLA  2021          1.5    Petrol          Manual
# ...          ...       ...   ...          ...       ...             ...
# 9974    Mercedes   C-Class  2020          1.1    Diesel          Manual
# 9980       Honda      CR-V  2012          1.5    Petrol          Manual
# 9987         BMW  5 Series  2004          1.3    Diesel          Manual
# 9992         BMW  5 Series  2016          1.2    Hybrid       Automatic
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
#
#       Mileage  Doors  Owner_Count  Price
# 1        5356      2            3  12092
# ...

# %%
data[data['Model']=='Suv']
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Year, Engine_Size, Fuel_Type, Transmission, Mileage, Doors, Owner_Count, Price]
# Index: []
